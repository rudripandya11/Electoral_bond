# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\91832\\Desktop\\DATA ANALYSIS\\DAY6'

# %%
os.chdir(r"C:\Users\91832\Desktop\DATA ANALYSIS\DAY6")

# %%
donors_data=pd.read_excel("donors_data.xlsx")
reciver_data=pd.read_excel("redemption_data.xlsx")

# %%
donors_data.head()
# Out:
#    Sr No.      Reference No  (URN) Journal Date Date of\nPurchase  \
# 0       1  00001201904120000001166   2019-04-12        2019-04-12
# 1       2  00001201904120000001166   2019-04-12        2019-04-12
# 2       3  00001201904120000001166   2019-04-12        2019-04-12
# 3       4  00001201904120000001166   2019-04-12        2019-04-12
# 4       5  00001201904120000001166   2019-04-12        2019-04-12
#
#   Date of Expiry Name of the Purchaser Prefix  Bond\nNumber  Denominations  \
# 0     2019-04-26   A B C INDIA LIMITED     TL         11448        1000000
# 1     2019-04-26   A B C INDIA LIMITED     TL         11447        1000000
# 2     2019-04-26   A B C INDIA LIMITED     TL         11441        1000000
# 3     2019-04-26   A B C INDIA LIMITED     OL          1113         100000
# 4     2019-04-26   A B C INDIA LIMITED     OL          1118         100000
#
#    Issue Branch Code  Issue Teller Status
# 0                  1       5899230   Paid
# ...

# %%
reciver_data.head()
# Out:
#    Sr No. Date of\nEncashment               Name of the Political Party  \
# 0       1          2019-04-12  ALL INDIA ANNA DRAVIDA MUNNETRA KAZHAGAM
# 1       2          2019-04-12  ALL INDIA ANNA DRAVIDA MUNNETRA KAZHAGAM
# 2       3          2019-04-12  ALL INDIA ANNA DRAVIDA MUNNETRA KAZHAGAM
# 3       4          2019-04-12  ALL INDIA ANNA DRAVIDA MUNNETRA KAZHAGAM
# 4       5          2019-04-12  ALL INDIA ANNA DRAVIDA MUNNETRA KAZHAGAM
#
#   Account no. of\nPolitical Party Prefix  Bond\nNumber  Denominations  \
# 0                     *******5199     OC           775       10000000
# 1                     *******5199     OC          3975       10000000
# 2                     *******5199     OC          3967       10000000
# 3                     *******5199     TL         10418        1000000
# 4                     *******5199     TL           126        1000000
#
#    Pay Branch\nCode  Pay Teller
# 0               800     2770121
# 1               800     2770121
# ...

# %%
donors_data.columns
# Out:
# Index(['Sr No.', 'Reference No  (URN)', 'Journal Date', 'Date of\nPurchase',
#        'Date of Expiry', 'Name of the Purchaser', 'Prefix', 'Bond\nNumber',
#        'Denominations', 'Issue Branch Code', 'Issue Teller', 'Status'],
#       dtype='object')

# %%
donors_data.rename(columns={"Reference No  (URN)":"Ref No" , "Date of\nPurchase" :"Purchase date","Bond\nNumber":"Bond No", "Denominations":"bond_amount"},inplace=True)

# %%
donors_data.columns
# Out:
# Index(['Sr No.', 'Ref No', 'Journal Date', 'Purchase date', 'Date of Expiry',
#        'Name of the Purchaser', 'Prefix', 'Bond No', 'bond_amount',
#        'Issue Branch Code', 'Issue Teller', 'Status'],
#       dtype='object')

# %%
reciver_data.columns
# Out:
# Index(['Sr No.', 'Date of\nEncashment', 'Name of the Political Party',
#        'Account no. of\nPolitical Party', 'Prefix', 'Bond\nNumber',
#        'Denominations', 'Pay Branch\nCode', 'Pay Teller'],
#       dtype='object')

# %%
reciver_data.rename(columns={"Bond\nNumber":"Bond No", "Date of\nEncashment":"encash_date","Pay Branch\nCode":"branch_code"},inplace=True)

# %%
reciver_data.columns
# Out:
# Index(['Sr No.', 'encash_date', 'Name of the Political Party',
#        'Account no. of\nPolitical Party', 'Prefix', 'Bond No', 'Denominations',
#        'branch_code', 'Pay Teller'],
#       dtype='object')

# %%
# To display the total amount of electron bond brought in cr
total_amt=donors_data["bond_amount"].sum()
total_amt_in_cr= total_amt/10000000
total_amt_in_cr=round(total_amt_in_cr,2)
print("total amt of eletro bond brought",total_amt_in_cr,"cr:")
# Out:
# total amt of eletro bond brought 12155.51 cr:

# %%
donors_data.sort_values(by="bond_amount").head()
# Out:
#        Sr No.                   Ref No Journal Date Purchase date  \
# 1831     1832  00001201905080000001375   2019-05-08    2019-05-08
# 1842     1843  00001201905080000001375   2019-05-08    2019-05-08
# 1843     1844  00001201905080000001375   2019-05-08    2019-05-08
# 1844     1845  00001201905080000001375   2019-05-08    2019-05-08
# 15879   15880  01355202310110000003394   2023-10-11    2023-10-11
#
#       Date of Expiry       Name of the Purchaser Prefix  Bond No  bond_amount  \
# 1831      2019-05-22                 ITC LIMITED     OT     5017         1000
# 1842      2019-05-22                 ITC LIMITED     OT     5013         1000
# 1843      2019-05-22                 ITC LIMITED     OT     5012         1000
# 1844      2019-05-22                 ITC LIMITED     OT     5018         1000
# 15879     2023-10-25  BHACHIBEN KHAMUBHAI MANVAR     OT    20076         1000
#
#        Issue Branch Code  Issue Teller Status
# 1831                   1       5899230   Paid
# ...

# %%
# To display the Name of the Purchaser in decending order with respect to bond amount 
donors_data.sort_values(by="bond_amount",ascending=False)[["Name of the Purchaser","bond_amount"]].head()
# Out:
#                      Name of the Purchaser  bond_amount
# 9435   FUTURE GAMING AND HOTEL SERVICES PR     10000000
# 10946                WELSPUN INDIA LIMITED     10000000
# 10934                      VEDANTA LIMITED     10000000
# 10935                      VEDANTA LIMITED     10000000
# 10936                      VEDANTA LIMITED     10000000

# %%
# To display the bonds purchased by a particular purchaser. Here I have taken "ITC LIMITED" .
donors_data[(donors_data["Name of the Purchaser"])=="ITC LIMITED"].head()
# Out:
#       Sr No.                   Ref No Journal Date Purchase date  \
# 1799    1800  00001201905080000001375   2019-05-08    2019-05-08
# 1800    1801  00001201905080000001375   2019-05-08    2019-05-08
# 1801    1802  00001201905080000001375   2019-05-08    2019-05-08
# 1802    1803  00001201905080000001375   2019-05-08    2019-05-08
# 1803    1804  00001201905080000001375   2019-05-08    2019-05-08
#
#      Date of Expiry Name of the Purchaser Prefix  Bond No  bond_amount  \
# 1799     2019-05-22           ITC LIMITED     OC     4698     10000000
# 1800     2019-05-22           ITC LIMITED     OC     4686     10000000
# 1801     2019-05-22           ITC LIMITED     OC     4700     10000000
# 1802     2019-05-22           ITC LIMITED     OC     7361     10000000
# 1803     2019-05-22           ITC LIMITED     OC     4682     10000000
#
#       Issue Branch Code  Issue Teller Status
# 1799                  1       5899230   Paid
# 1800                  1       5899230   Paid
# ...

# %%
# count total no of rows we got
len(donors_data[(donors_data["Name of the Purchaser"])=="ITC LIMITED"])
# Out:
# 46

# %%
#lets say i want to put mulitple condition like purcharser should be itc and bond_amount should be greater than or equal to 1cr
donors_data[(donors_data['Name of the Purchaser']=="ITC LIMITED") & (donors_data['bond_amount']>=10000000)][["Name of the Purchaser","bond_amount"]]
# Out:
#      Name of the Purchaser  bond_amount
# 1799           ITC LIMITED     10000000
# 1800           ITC LIMITED     10000000
# 1801           ITC LIMITED     10000000
# 1802           ITC LIMITED     10000000
# 1803           ITC LIMITED     10000000

# %%
# i want to know unique entities (or donors) who has donate
donors_data['bond_amount'].unique()
# Out:
# array([ 1000000,   100000, 10000000,     1000,    10000], dtype=int64)

# %%
donors_data["bond_amount"].value_counts()
# Out:
# bond_amount
# 10000000    11671
# 1000000      4620
# 100000       2228
# 10000         220
# 1000          132
# Name: count, dtype: int64

# %%
reciver_data.columns
# Out:
# Index(['Sr No.', 'encash_date', 'Name of the Political Party',
#        'Account no. of\nPolitical Party', 'Prefix', 'Bond No', 'Denominations',
#        'branch_code', 'Pay Teller'],
#       dtype='object')

# %%
#want to see not just unique party but how many times that info is comming the raw data
reciver_data["Name of the Political Party"].value_counts()
# Out:
# Name of the Political Party
# BHARATIYA JANATA PARTY                                          8633
# ALL INDIA TRINAMOOL CONGRESS                                    3305
# PRESIDENT, ALL INDIA CONGRESS COMMITTEE                         3146
# BHARAT RASHTRA SAMITHI                                          1806
# BIJU JANATA DAL                                                  861
# DRAVIDA MUNNETRA KAZHAGAM (DMK)                                  648
# YSR  CONGRESS PARTY  (YUVAJANA SRAMIKA RYTHU CONGRESS PARTY)     472
# SHIVSENA                                                         355
# TELUGU DESAM PARTY                                               279
# AAM AADMI PARTY                                                  245
# RASHTRIYA JANTA DAL                                              150
# NATIONALIST CONGRESS PARTY MAHARASHTRA PRADESH                   121
# JANATA DAL ( SECULAR )                                            75
# ...

# %%
#know is there any missing value?
print(reciver_data.isnull().sum())
print(donors_data.isnull().sum())
# Out:
# Sr No.                             0
# encash_date                        0
# Name of the Political Party        0
# Account no. of\nPolitical Party    0
# Prefix                             0
# Bond No                            0
# Denominations                      0
# branch_code                        0
# Pay Teller                         0
# dtype: int64
# Sr No.                   0
# Ref No                   0
# Journal Date             0
# Purchase date            0
# Date of Expiry           0
# Name of the Purchaser    0
# Prefix                   0
# Bond No                  0
# bond_amount              0
# Issue Branch Code        0
# Issue Teller             0
# Status                   0
# dtype: int64

# %%
#Q1 : I want to identify that total how much amount of the bond is paid and how much amount of the bond is expired
donors_data.groupby(["Status"])["bond_amount"].sum()
# Out:
# Status
# Expired        96349000
# Paid       121458783000
# Name: bond_amount, dtype: int64

# %%
donors_data.columns
# Out:
# Index(['Sr No.', 'Ref No', 'Journal Date', 'Purchase date', 'Date of Expiry',
#        'Name of the Purchaser', 'Prefix', 'Bond No', 'bond_amount',
#        'Issue Branch Code', 'Issue Teller', 'Status'],
#       dtype='object')

# %%
#Q2 : How much each party got as the bond amount
reciver_data.groupby(["Name of the Political Party"])['Denominations'].sum()
# Out:
# Name of the Political Party
# AAM AADMI PARTY                                                   654500000
# ADYAKSHA SAMAJVADI PARTY                                          140500000
# ALL INDIA ANNA DRAVIDA MUNNETRA KAZHAGAM                           60500000
# ALL INDIA TRINAMOOL CONGRESS                                    16095314000
# BHARAT RASHTRA SAMITHI                                          12147099000
# BHARATIYA JANATA PARTY                                          60605111000
# BIHAR PRADESH JANTA DAL(UNITED)                                   140000000
# BIJU JANATA DAL                                                  7755000000
# DRAVIDA MUNNETRA KAZHAGAM (DMK)                                  6390000000
# GOA FORWARD PARTY                                                   3500000
# JAMMU AND KASHMIR NATIONAL CONFERENCE                               5000000
# JANASENA PARTY                                                    210000000
# ...

# %%
party_with_fund=pd.DataFrame(reciver_data.groupby(['Name of the Political Party'])['Denominations'].sum())

# %%
#Q3 : TOP 5 Parties who got the highest amount of the fund
party_with_fund.sort_values(by="Denominations",ascending=False).head()
# Out:
#                                          Denominations
# Name of the Political Party
# BHARATIYA JANATA PARTY                     60605111000
# ALL INDIA TRINAMOOL CONGRESS               16095314000
# PRESIDENT, ALL INDIA CONGRESS COMMITTEE    14218655000
# BHARAT RASHTRA SAMITHI                     12147099000
# BIJU JANATA DAL                             7755000000

# %%
reciver_data.rename(columns = { "Bond_No":"Bond No"},inplace=True)

# %%
#JOIN THE TWO DATA:
#On which column we can join?
reciver_data.head()
# Out:
#    Sr No. encash_date               Name of the Political Party  \
# 0       1  2019-04-12  ALL INDIA ANNA DRAVIDA MUNNETRA KAZHAGAM
# 1       2  2019-04-12  ALL INDIA ANNA DRAVIDA MUNNETRA KAZHAGAM
# 2       3  2019-04-12  ALL INDIA ANNA DRAVIDA MUNNETRA KAZHAGAM
# 3       4  2019-04-12  ALL INDIA ANNA DRAVIDA MUNNETRA KAZHAGAM
# 4       5  2019-04-12  ALL INDIA ANNA DRAVIDA MUNNETRA KAZHAGAM
#
#   Account no. of\nPolitical Party Prefix  Bond No  Denominations  branch_code  \
# 0                     *******5199     OC      775       10000000          800
# 1                     *******5199     OC     3975       10000000          800
# 2                     *******5199     OC     3967       10000000          800
# 3                     *******5199     TL    10418        1000000          800
# 4                     *******5199     TL      126        1000000          800
#
#    Pay Teller
# 0     2770121
# 1     2770121
# 2     2770121
# 3     2770121
# 4     2770121

# %%
donors_data.head()
# Out:
#    Sr No.                   Ref No Journal Date Purchase date Date of Expiry  \
# 0       1  00001201904120000001166   2019-04-12    2019-04-12     2019-04-26
# 1       2  00001201904120000001166   2019-04-12    2019-04-12     2019-04-26
# 2       3  00001201904120000001166   2019-04-12    2019-04-12     2019-04-26
# 3       4  00001201904120000001166   2019-04-12    2019-04-12     2019-04-26
# 4       5  00001201904120000001166   2019-04-12    2019-04-12     2019-04-26
#
#   Name of the Purchaser Prefix  Bond No  bond_amount  Issue Branch Code  \
# 0   A B C INDIA LIMITED     TL    11448      1000000                  1
# 1   A B C INDIA LIMITED     TL    11447      1000000                  1
# 2   A B C INDIA LIMITED     TL    11441      1000000                  1
# 3   A B C INDIA LIMITED     OL     1113       100000                  1
# 4   A B C INDIA LIMITED     OL     1118       100000                  1
#
#    Issue Teller Status
# 0       5899230   Paid
# ...

# %%
combined_data=pd.merge(donors_data,reciver_data,on="Bond No",how="inner")

# %%
combined_data.head()
# Out:
#    Sr No._x                   Ref No Journal Date Purchase date  \
# 0         1  00001201904120000001166   2019-04-12    2019-04-12
# 1         1  00001201904120000001166   2019-04-12    2019-04-12
# 2     11034  00001202211150000002706   2022-11-15    2022-11-15
# 3     11034  00001202211150000002706   2022-11-15    2022-11-15
# 4         2  00001201904120000001166   2019-04-12    2019-04-12
#
#   Date of Expiry        Name of the Purchaser Prefix_x  Bond No  bond_amount  \
# 0     2019-04-26          A B C INDIA LIMITED       TL    11448      1000000
# 1     2019-04-26          A B C INDIA LIMITED       TL    11448      1000000
# 2     2022-11-29  IFB AGRO INDUSTRIES LIMITED       OC    11448     10000000
# 3     2022-11-29  IFB AGRO INDUSTRIES LIMITED       OC    11448     10000000
# 4     2019-04-26          A B C INDIA LIMITED       TL    11447      1000000
#
#    Issue Branch Code  Issue Teller Status  Sr No._y encash_date  \
# ...

# %%
combined_data.columns
# Out:
# Index(['Sr No._x', 'Ref No', 'Journal Date', 'Purchase date', 'Date of Expiry',
#        'Name of the Purchaser', 'Prefix_x', 'Bond No', 'bond_amount',
#        'Issue Branch Code', 'Issue Teller', 'Status', 'Sr No._y',
#        'encash_date', 'Name of the Political Party',
#        'Account no. of\nPolitical Party', 'Prefix_y', 'Denominations',
#        'branch_code', 'Pay Teller'],
#       dtype='object')

# %%
corr_info=combined_data[['Name of the Purchaser','Bond No', 'bond_amount','Name of the Political Party']]

# %%
corr_info.head()
# Out:
#          Name of the Purchaser  Bond No  bond_amount  \
# 0          A B C INDIA LIMITED    11448      1000000
# 1          A B C INDIA LIMITED    11448      1000000
# 2  IFB AGRO INDUSTRIES LIMITED    11448     10000000
# 3  IFB AGRO INDUSTRIES LIMITED    11448     10000000
# 4          A B C INDIA LIMITED    11447      1000000
#
#                Name of the Political Party
# 0                   BHARATIYA JANATA PARTY
# 1  PRESIDENT, ALL INDIA CONGRESS COMMITTEE
# 2                   BHARATIYA JANATA PARTY
# 3  PRESIDENT, ALL INDIA CONGRESS COMMITTEE
# 4                   BHARATIYA JANATA PARTY

# %%
#Q4 : who are the top donors of BJP
bjp_data=corr_info[corr_info['Name of the Political Party']=='BHARATIYA JANATA PARTY']

# %%
bjp_data
# Out:
#                 Name of the Purchaser  Bond No  bond_amount  \
# 0                 A B C INDIA LIMITED    11448      1000000
# 2         IFB AGRO INDUSTRIES LIMITED    11448     10000000
# 4                 A B C INDIA LIMITED    11447      1000000
# 6      WESTWELL GASES PRIVATE LIMITED    11447     10000000
# 8                 A B C INDIA LIMITED    11441      1000000
# ...                               ...      ...          ...
# 28673               RUNGTA SONS P LTD    15783     10000000
# 28674               RUNGTA SONS P LTD    17831     10000000
# 28675               RUNGTA SONS P LTD    16480     10000000
# 28676               RUNGTA SONS P LTD    17819     10000000
# 28677               RUNGTA SONS P LTD    16476     10000000
#
#       Name of the Political Party
# 0          BHARATIYA JANATA PARTY
# 2          BHARATIYA JANATA PARTY
# 4          BHARATIYA JANATA PARTY
# 6          BHARATIYA JANATA PARTY
# 8          BHARATIYA JANATA PARTY
# ...

# %%
grouped_data=bjp_data.groupby('Name of the Purchaser')['bond_amount'].sum()

# %%
top_5_bjp_donors=grouped_data.sort_values(ascending=False).head(5)

# %%
top_5_bjp_donors=top_5_bjp_donors.reset_index()

# %%
top_5_bjp_donors
# Out:
#                             Name of the Purchaser  bond_amount
# 0  MEGHA ENGINEERING AND INFRASTRUCTURES LI MITED   6010000000
# 1                   QWIKSUPPLYCHAINPRIVATELIMITED   5640000000
# 2                                 VEDANTA LIMITED   3229500000
# 3                           BHARTI AIRTEL LIMITED   1860000000
# 4                                   MADANLAL LTD.   1820000000

# %%
top_5_bjp_donors.to_csv(r"top_5_bjp_donors.csv")

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\91832\\Desktop\\DATA ANALYSIS\\DAY6'

# %%
#Q5 Amount reedemed by a recepient party but no donors available? 
unique_bond_no_in_receiver=reciver_data["Bond No"].unique()

# %%
unique_bond_no_in_receiver=list(unique_bond_no_in_receiver)

# %%
unique_bond_no_in_receiver
# Out:
# [775,
#  3975,
#  3967,
#  10418,
#  126,
#  116,
#  10466,
#  122,
#  158,
#  108,
#  10446,
#  10434,
#  162,
#  128,
#  113,
#  10423,
#  110,
#  131,
#  164,
#  118,
#  10449,
#  10417,
#  10426,
#  10420,
#  10443,
#  10452,
#  160,
#  10408,
#  120,
#  10464,
#  124,
#  10440,
#  10469,
#  6646,
#  6644,
#  5470,
#  5455,
#  5467,
#  5460,
#  5463,
#  5451,
#  5458,
#  5454,
#  5474,
#  5459,
#  5475,
#  5464,
#  5453,
#  5472,
#  5471,
#  5468,
#  5450,
#  5462,
#  5457,
#  5466,
#  10876,
#  10877,
#  10885,
#  10856,
#  10870,
#  4274,
#  4276,
#  5827,
#  5847,
#  4303,
#  4301,
#  5831,
#  4321,
#  5861,
#  4325,
#  5843,
#  5837,
#  5817,
#  4319,
#  4293,
#  4305,
#  5801,
#  5825,
#  4313,
#  5805,
#  5829,
#  5821,
#  5839,
#  5841,
#  5813,
#  5833,
#  4327,
#  4311,
#  4347,
#  4317,
#  5809,
#  5855,
#  4333,
#  4335,
#  4337,
#  4343,
#  4295,
#  4331,
#  5819,
#  5853,
#  5857,
#  4349,
#  5803,
#  5849,
#  4299,
#  4329,
#  4315,
#  4339,
#  5835,
#  5807,
# ...

# %%
unique_bond_no_in_donor=donors_data["Bond No"].unique()
unique_bond_no_in_donor=list(unique_bond_no_in_donor)

# %%
difference= set(unique_bond_no_in_receiver)-set(unique_bond_no_in_donor)

# %%
len(difference)
# Out:
# 860

# %%
bond_no_match_not_found=list(difference)

# %%
match_not_found_in_donor=reciver_data[reciver_data["Bond No"].isin(difference)]

# %%
match_not_found_in_donor
# Out:
#       Sr No. encash_date               Name of the Political Party  \
# 0          1  2019-04-12  ALL INDIA ANNA DRAVIDA MUNNETRA KAZHAGAM
# 1          2  2019-04-12  ALL INDIA ANNA DRAVIDA MUNNETRA KAZHAGAM
# 2          3  2019-04-12  ALL INDIA ANNA DRAVIDA MUNNETRA KAZHAGAM
# 4          5  2019-04-12  ALL INDIA ANNA DRAVIDA MUNNETRA KAZHAGAM
# 5          6  2019-04-12  ALL INDIA ANNA DRAVIDA MUNNETRA KAZHAGAM
# ...      ...         ...                                       ...
# 2801    2802  2019-04-25                    BHARATIYA JANATA PARTY
# 2804    2805  2019-04-25                    BHARATIYA JANATA PARTY
# 2853    2854  2019-04-25                                  SHIVSENA
# 2854    2855  2019-04-25                                  SHIVSENA
# 2855    2856  2019-04-25                                  SHIVSENA
#
#      Account no. of\nPolitical Party Prefix  Bond No  Denominations  \
# 0                        *******5199     OC      775       10000000
# ...

# %%
match_not_found_in_donor['Denominations'].sum()
# Out:
# 5345110000

# %%
x=match_not_found_in_donor.groupby(['Name of the Political Party'])['Denominations'].sum()

# %%
x.sort_values(ascending=False)
# Out:
# Name of the Political Party
# BHARATIYA JANATA PARTY                                          4132000000
# PRESIDENT, ALL INDIA CONGRESS COMMITTEE                          548710000
# BHARAT RASHTRA SAMITHI                                           230500000
# ALL INDIA TRINAMOOL CONGRESS                                     130000000
# YSR  CONGRESS PARTY  (YUVAJANA SRAMIKA RYTHU CONGRESS PARTY)      70500000
# DRAVIDA MUNNETRA KAZHAGAM (DMK)                                   60000000
# TELUGU DESAM PARTY                                                60000000
# ALL INDIA ANNA DRAVIDA MUNNETRA KAZHAGAM                          45400000
# SHIVSENA                                                          40300000
# BIHAR PRADESH JANTA DAL(UNITED)                                   20000000
# ADYAKSHA SAMAJVADI PARTY                                           7700000
# Name: Denominations, dtype: int64

# %%
highest_amt=donors_data.groupby(['Name of the Purchaser'])['bond_amount']

# %%
highest_amt

# %%
df=pd.DataFrame(donors_data)
df
# Out:
#        Sr No.                   Ref No Journal Date Purchase date  \
# 0           1  00001201904120000001166   2019-04-12    2019-04-12
# 1           2  00001201904120000001166   2019-04-12    2019-04-12
# 2           3  00001201904120000001166   2019-04-12    2019-04-12
# 3           4  00001201904120000001166   2019-04-12    2019-04-12
# 4           5  00001201904120000001166   2019-04-12    2019-04-12
# ...       ...                      ...          ...           ...
# 18866   18867  00001202401110000003729   2024-01-11    2024-01-11
# 18867   18868  00001202401110000003729   2024-01-11    2024-01-11
# 18868   18869  00001202401110000003729   2024-01-11    2024-01-11
# 18869   18870  00001202401110000003729   2024-01-11    2024-01-11
# 18870   18871  00001202401110000003729   2024-01-11    2024-01-11
#
#       Date of Expiry           Name of the Purchaser Prefix  Bond No  \
# 0         2019-04-26             A B C INDIA LIMITED     TL    11448
# ...

# %%
#Q6 Which person/company has bought highest amount of bond but havent clamied by any party?
unclaimed_bonds = df[df['Status'] == 'Expired']
unclaimed_bonds
# Out:
#        Sr No.                   Ref No Journal Date Purchase date  \
# 443       444  00300201904150000001198   2019-04-15    2019-04-15
# 444       445  00300201904150000001198   2019-04-15    2019-04-15
# 556       557  00300201904160000001220   2019-04-16    2019-04-16
# 830       831  00001201904170000001245   2019-04-17    2019-04-17
# 831       832  00001201904170000001245   2019-04-17    2019-04-17
# ...       ...                      ...          ...           ...
# 18815   18816  01355202401110000003743   2024-01-11    2024-01-11
# 18816   18817  01355202401110000003743   2024-01-11    2024-01-11
# 18817   18818  01355202401110000003743   2024-01-11    2024-01-11
# 18818   18819  01355202401110000003743   2024-01-11    2024-01-11
# 18819   18820  01355202401110000003743   2024-01-11    2024-01-11
#
#       Date of Expiry                Name of the Purchaser Prefix  Bond No  \
# 443       2019-04-29  UTKAL ALUMINA INTERNATIONAL LIMITED     TL    12858
# ...

# %%
# Q7 For which amount highest no of bond purchased?
unclaimed_sum = unclaimed_bonds.groupby('Name of the Purchaser')['bond_amount'].sum()
unclaimed_sum
# Out:
# Name of the Purchaser
# ADWITA FINVEST PRIVATE LIMITED                    1000
# ANAND AGRAWAL                                    25000
# ANKUR SINGHAL S O SH  ANIL SIN                    1000
# BRINDABAN NASKAR                                500000
# C MACKERTICH PVT LTD                           4000000
# CHENNAMANAGATHIHALLI SOLAR POWER PROJECT        600000
# DAMINI NATH                                       1000
# DIPAN  P  SHAH                                  300000
# ECL FINANCE LTD                               20000000
# EDELWEISS RURAL   CORPORATE SERVICE           10000000
# FUTURE GAMING AND HOTEL SERVICES PR           30000000
# JUPITER MERCANTILES PVT LTD                    2500000
# KEYSTONE REALTORS PVT LTD                      1000000
# KUNAL GUPTA                                       1000
# MR GIRIDARAN MANIVANNAN                           3000
# MR. ABHIJEET SOLOMAN KAMBLE                       4000
# MR. BISWAJIT  GHOSH                               2000
# ...

# %%
highest_unclaimed_buyer = unclaimed_sum.idxmax()
highest_unclaimed_amount = unclaimed_sum.max()

highest_unclaimed_amount,highest_unclaimed_buyer
# Out:
# (30000000, 'FUTURE GAMING AND HOTEL SERVICES PR')

# %%
#Q8 For which amount highest no of bond purchased?
amount_counts = df['bond_amount'].value_counts()
amount_counts
# Out:
# bond_amount
# 10000000    11671
# 1000000      4620
# 100000       2228
# 10000         220
# 1000          132
# Name: count, dtype: int64

# %%
max_purchased_amount = amount_counts.idxmax()
max_purchases = amount_counts.max()

print(f"The amount with the highest number of bond purchases is {max_purchased_amount} with {max_purchases} purchases.")
# Out:
# The amount with the highest number of bond purchases is 10000000 with 11671 purchases.

# %%
#Q9 What if i want to identify percentage not the actual number.
amount_counts = donors_data['bond_amount'].value_counts()
total_purchases = amount_counts.sum()
amount_percentages = (amount_counts / total_purchases) * 100

# Find the amount with the highest percentage of purchases
max_purchased_amount = amount_percentages.idxmax()
max_purchase_percentage = amount_percentages.max()

print(f"The amount with the highest percentage of bond purchases is {max_purchased_amount} with {max_purchase_percentage:.2f}% of the total purchases.")
# Out:
# The amount with the highest percentage of bond purchases is 10000000 with 61.85% of the total purchases.

# %%
#Q10 Calculate total bond_amount for each political party
total_bond_amount = reciver_data.groupby('Name of the Political Party')['Denominations'].sum().reset_index()
print(total_bond_amount)
# Out:
#                           Name of the Political Party  Denominations
# 0                                     AAM AADMI PARTY      654500000
# 1                            ADYAKSHA SAMAJVADI PARTY      140500000
# 2            ALL INDIA ANNA DRAVIDA MUNNETRA KAZHAGAM       60500000
# 3                        ALL INDIA TRINAMOOL CONGRESS    16095314000
# 4                              BHARAT RASHTRA SAMITHI    12147099000
# 5                              BHARATIYA JANATA PARTY    60605111000
# 6                     BIHAR PRADESH JANTA DAL(UNITED)      140000000
# 7                                     BIJU JANATA DAL     7755000000
# 8                     DRAVIDA MUNNETRA KAZHAGAM (DMK)     6390000000
# 9                                   GOA FORWARD PARTY        3500000
# 10              JAMMU AND KASHMIR NATIONAL CONFERENCE        5000000
# 11                                     JANASENA PARTY      210000000
# 12                             JANATA DAL ( SECULAR )      435000000
# ...

# %%
#Q11 First and last bond purchased date
donors_data['Purchase date'] = pd.to_datetime(donors_data['Purchase date'])

# Find the first and last bond purchased date, along with the corresponding donor
first_bond_purchased = donors_data.loc[donors_data['Purchase date'].idxmin()]
last_bond_purchased = donors_data.loc[donors_data['Purchase date'].idxmax()]

print("First bond purchased:")
print(f"Date: {first_bond_purchased['Purchase date']}")
print(f"Donor: {first_bond_purchased['Name of the Purchaser']}")

print("\nLast bond purchased:")
print(f"Date: {last_bond_purchased['Purchase date']}")
print(f"Donor: {last_bond_purchased['Name of the Purchaser']}")
# Out:
# First bond purchased:
# Date: 2019-04-12 00:00:00
# Donor: A B C INDIA LIMITED
#
# Last bond purchased:
# Date: 2024-01-11 00:00:00
# Donor: ABHINANDANSTOCKBROKINGPVTLTD

# %%
#Q12 First and last bond reedemed date
reciver_data['encash_date'] = pd.to_datetime(reciver_data['encash_date'])

# Find the first and last bond redeemed date, along with the corresponding political party
first_bond_encashed = reciver_data.loc[reciver_data['encash_date'].idxmin()]
last_bond_encashed = reciver_data.loc[reciver_data['encash_date'].idxmax()]

print("First bond encashed:")
print(f"Party: {first_bond_encashed['Name of the Political Party']}")
print(f"Date: {first_bond_encashed['encash_date']}")

print("\nLast bond encashed:")
print(f"Party: {last_bond_encashed['Name of the Political Party']}")
print(f"Date: {last_bond_encashed['encash_date']}")
# Out:
# First bond encashed:
# Party: ALL INDIA ANNA DRAVIDA MUNNETRA KAZHAGAM
# Date: 2019-04-12 00:00:00
#
# Last bond encashed:
# Party: BHARATIYA JANATA PARTY
# Date: 2024-01-24 00:00:00

# %%
#Q13 Year wise bond purchased and claimed
df['Journal Date'] = pd.to_datetime(df['Journal Date'])

# Calculate the year from the date
df['Journal Year'] = df['Journal Date'].dt.year

# Group the data by year and count the number of bonds
purchase_counts = df.groupby('Journal Year')['Status'].count().reset_index()

# Filter the claimed bonds
claimed_bonds = df[df['Status'] == 'Paid']

# Calculate the year from the date of claimed bonds
claimed_bonds['Journal Year'] = claimed_bonds['Journal Date'].dt.year

# Group the claimed bonds by year and count the number of bonds
claim_counts = claimed_bonds.groupby('Journal Year')['Status'].count().reset_index()

print("Year-wise Bond Purchases:")
print(purchase_counts)
print("\nYear-wise Bond Claims:")
print(claim_counts)
# Out:
# Year-wise Bond Purchases:
#    Journal Year  Status
# 0          2019    3154
# 1          2020     460
# 2          2021    2647
# 3          2022    5314
# 4          2023    6399
# 5          2024     897
#
# Year-wise Bond Claims:
#    Journal Year  Status
# 0          2019    3103
# 1          2020     459
# 2          2021    2642
# 3          2022    5300
# 4          2023    6365
# 5          2024     872
# C:\Users\91832\AppData\Local\Temp\ipykernel_30612\3223072555.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   claimed_bonds['Journal Year'] = claimed_bonds['Journal Date'].dt.year
